# %%
import pandas as pd
import numpy as np
import os

# %%
# df = pd.read_csv(os.path.expanduser('~/Data/Bilingualism_CVAE/raw/ping/participants.tsv'), sep="\t")
image = pd.read_csv(os.path.expanduser('~/Ping/image03.txt'), sep="\t")
data = pd.read_csv(os.path.expanduser('~/Ping/fdh01.txt'), sep="\t")
#refer to https://nda.nih.gov/data_structure.html?short_name=fdh01
image['scanner_type_pd'].value_counts(dropna=False)
# Out:
# TrioTim                1884
# Achieva                 998
# DISCOVERY MR750         543
# SIGNA HDx               431
# Equipment Type/name       1
# Name: scanner_type_pd, dtype: int64

# %%
image
# Out:
#       collection_id  image03_id  dataset_id  \
# 0     collection_id  image03_id  dataset_id
# 1              2607     1665100       17149
# 2              2607     1665101       17149
# 3              2607     1665102       17149
# 4              2607     1665103       17149
# ...             ...         ...         ...
# 3852           2607     1667027       17155
# 3853           2607     1667028       17155
# 3854           2607     1667029       17155
# 3855           2607     1667030       17155
# 3856           2607     1667031       17155
#
#                                              subjectkey  \
# 0     The NDAR Global Unique Identifier (GUID) for r...
# 1                                      NDAR_INV8J9E98PE
# 2                                      NDAR_INV2W9ZVNMW
# 3                                      NDAR_INVG0GL0FNJ
# 4                                      NDAR_INVJFVP8H6H
# ...                                                 ...
# 3852                                   NDAR_INVUCUMRTJM
# 3853                                   NDAR_INV9EUY202W
# 3854                                   NDAR_INVXZF8Y413
# 3855                                   NDAR_INV90JTKNHX
# 3856                                   NDAR_INV07T9ACEG
#
#                                   src_subject_id  \
# 0     Subject ID how it's defined in lab/project
# 1                                          P0301
# 2                                          P0302
# 3                                          P0303
# 4                                          P0310
# ...                                          ...
# 3852                                       P0332
# 3853                                       P0348
# 3854                                       P0358
# 3855                                       P0360
# 3856                                       P0367
#
#                                          interview_date  \
# 0     Date on which the interview/genetic test/sampl...
# 1                                            01/01/2011
# 2                                            01/01/2011
# 3                                            01/01/2011
# 4                                            01/01/2011
# ...                                                 ...
# 3852                                         01/01/2011
# 3853                                         01/01/2011
# 3854                                         01/01/2011
# 3855                                         01/01/2011
# 3856                                         01/01/2011
#
#                                           interview_age  \
# 0     Age in months at the time of the interview/tes...
# 1                                                   141
# 2                                                   249
# 3                                                   233
# 4                                                   196
# ...                                                 ...
# 3852                                                121
# 3853                                                128
# 3854                                                222
# 3855                                                 82
# 3856                                                207
#
#                           sex  \
# 0     Sex of subject at birth
# 1                           M
# 2                           F
# 3                           F
# 4                           M
# ...                       ...
# 3852                        F
# 3853                        F
# 3854                        M
# 3855                        M
# 3856                        M
#
#                                           comments_misc  \
# 0     Miscellaneous comments on study, interview, me...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3852                                                NaN
# 3853                                                NaN
# 3854                                                NaN
# 3855                                                NaN
# 3856                                                NaN
#
#                                              image_file  ...  \
# 0        Data file (image, behavioral, anatomical, etc)  ...
# 1     s3://NDAR_Central_1/submission_17020/localizer...  ...
# 2     s3://NDAR_Central_1/submission_17020/localizer...  ...
# 3     s3://NDAR_Central_1/submission_17020/localizer...  ...
# 4     s3://NDAR_Central_1/submission_17020/localizer...  ...
# ...                                                 ...  ...
# 3852  s3://NDAR_Central_2/submission_17025/b0_map/P0...  ...
# 3853  s3://NDAR_Central_2/submission_17025/b0_map/P0...  ...
# 3854  s3://NDAR_Central_2/submission_17025/b0_map/P0...  ...
# 3855  s3://NDAR_Central_2/submission_17025/b0_map/P0...  ...
# 3856  s3://NDAR_Central_2/submission_17025/b0_map/P0...  ...
#
#                     excitation_wavelength       year_mta  \
# 0     excitation wavelength in nanometers  Year in study
# 1                                     NaN            NaN
# 2                                     NaN            NaN
# 3                                     NaN            NaN
# 4                                     NaN            NaN
# ...                                   ...            ...
# 3852                                  NaN            NaN
# 3853                                  NaN            NaN
# 3854                                  NaN            NaN
# 3855                                  NaN            NaN
# 3856                                  NaN            NaN
#
#             timepoint_label                   aqi  \
# 0     Timepoint/visit label  AFNI?s quality index
# 1                       NaN                   NaN
# 2                       NaN                   NaN
# 3                       NaN                   NaN
# 4                       NaN                   NaN
# ...                     ...                   ...
# 3852                    NaN                   NaN
# 3853                    NaN                   NaN
# 3854                    NaN                   NaN
# 3855                    NaN                   NaN
# 3856                    NaN                   NaN
#
#                                  fd_mean  \
# 0     Mean frame wise displacement in mm
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 3852                                 NaN
# 3853                                 NaN
# 3854                                 NaN
# 3855                                 NaN
# 3856                                 NaN
#
#                                               dvars_std  \
# 0     Index the rate of change of BOLD signal across...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3852                                                NaN
# 3853                                                NaN
# 3854                                                NaN
# 3855                                                NaN
# 3856                                                NaN
#
#                                 tsnr  \
# 0     Temporal signal to noise ratio
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 3852                             NaN
# 3853                             NaN
# 3854                             NaN
# 3855                             NaN
# 3856                             NaN
#
#                                              fetal_age  \
# 0     Age of the fetus (i.e., gestational age) in days
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 3852                                               NaN
# 3853                                               NaN
# 3854                                               NaN
# 3855                                               NaN
# 3856                                               NaN
#
#                                   fetal_age_type  \
# 0     Type of gestational age used for fetal_age
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 3852                                         NaN
# 3853                                         NaN
# 3854                                         NaN
# 3855                                         NaN
# 3856                                         NaN
#
#                                        collection_title
# 0                                      collection_title
# 1     Pediatric Imaging, Neurocognition, and Genetic...
# 2     Pediatric Imaging, Neurocognition, and Genetic...
# 3     Pediatric Imaging, Neurocognition, and Genetic...
# 4     Pediatric Imaging, Neurocognition, and Genetic...
# ...                                                 ...
# 3852  Pediatric Imaging, Neurocognition, and Genetic...
# 3853  Pediatric Imaging, Neurocognition, and Genetic...
# 3854  Pediatric Imaging, Neurocognition, and Genetic...
# 3855  Pediatric Imaging, Neurocognition, and Genetic...
# 3856  Pediatric Imaging, Neurocognition, and Genetic...
#
# [3857 rows x 119 columns]

# %%
image.columns[0:50]
image.scan_type.value_counts()
# Out:
# MR structural (T1)        783
# MR diffusion              761
# MR structural (T2)        735
# Localizer scan            706
# fMRI                      461
# MR structural (B0 map)    410
# Type of Scan                1
# Name: scan_type, dtype: int64

# %%
#check the same subjects have multiple T1 results
subs = image[image.scan_type == 'MR structural (T1)']['src_subject_id'].value_counts()
subs_index = subs[subs==2].index
subs_index = subs_index.tolist()

# %%
len(subs_index) #22 duplicates
# Out:
# 22

# %%
dup = image[(image.src_subject_id.isin(subs_index)) & (image.scan_type == 'MR structural (T1)')][['src_subject_id', 'scanner_type_pd']]
#all T1 here are TrioTim, except P0008, couldn't decide the scanner of P0008, so use NA instead.

# %%
data = data.iloc[1:, :]
len(data)
# Out:
# 1493

# %%
#ds, participant_id, bilingualism(0-no, 1-yes)
#age, sex(F,M), scanner
#aoa/aoa_group(EB, LB), num_lan, sec_lan_proficiency(0-1), sec_lan_exposure(0-1)

# %%
scanner = image[(image.scan_type == 'MR structural (T1)')].loc[:, ['src_subject_id', 'scanner_type_pd']]
scanner.loc[scanner.src_subject_id=='P0008', 'scanner_type_pd'] = None
scanner = scanner.drop_duplicates(keep='first') #from 783 to 761, 22 removed

# %%
data = data.merge(scanner, how='left', on='src_subject_id')

# %%
data = data.copy()
data.loc[:, 'participant_id'] = 'sub-'+data.loc[:, 'src_subject_id']

# %%
data.loc[:, 'scanner'] = data.loc[:, 'scanner_type_pd']

# %%
data.loc[:, 'bilingualism'] = data.loc[:, 'fdh_22_speaks_othr_lang']
data.loc[data['bilingualism']=='2','bilingualism']=0
data.loc[data['bilingualism']=='1','bilingualism']=1

# %%
data.loc[:, 'age'] = data.loc[:, 'interview_age'].astype(float)/12
#data['age'].mean() is 11.34

# %%
data['interview_age'].astype(float).hist(bins=5).set_xticks([0, 25, 50,75,100,125,150,175,200,225,250])
# Out:
# [<matplotlib.axis.XTick at 0x155529da8bb0>,
#  <matplotlib.axis.XTick at 0x155529da8be0>,
#  <matplotlib.axis.XTick at 0x155529b75a90>,
#  <matplotlib.axis.XTick at 0x155529b3b310>,
#  <matplotlib.axis.XTick at 0x155529b3b820>,
#  <matplotlib.axis.XTick at 0x155529b3bd30>,
#  <matplotlib.axis.XTick at 0x155529b3b9a0>,
#  <matplotlib.axis.XTick at 0x155529b43280>,
#  <matplotlib.axis.XTick at 0x155529b43790>,
#  <matplotlib.axis.XTick at 0x155529b43ca0>,
#  <matplotlib.axis.XTick at 0x155529b491f0>]

# %%
data.age.describe()
data.age.hist()

# %%
data.loc[:, 'ds'] = 'ping'

# %%
legend = data.loc[:, ['participant_id', 'bilingualism', 'age', 'sex', 
              'ds', 'scanner']]

# %%
legend.to_csv(
    os.path.expanduser('~/Documents/Bilingualism_CVAE/data/legend/ping.csv'),
    index = False)
